# %% [markdown]
# ## Ungraded Lab: MNIST Autoencoder
#
# You will now work on an autoencoder that works on the [MNIST dataset](https://www.tensorflow.org/datasets/catalog/mnist). This will encode the inputs to lower resolution images. The decoder should then be able to generate the original input from this compressed representation.

# %%
# !pip install tensorflow_datasets
# Out:
# Requirement already satisfied: tensorflow_datasets in d:\school captian\lib\site-packages (4.9.6)
# Requirement already satisfied: absl-py in d:\school captian\lib\site-packages (from tensorflow_datasets) (2.1.0)
# Requirement already satisfied: click in d:\school captian\lib\site-packages (from tensorflow_datasets) (8.1.7)
# Requirement already satisfied: dm-tree in d:\school captian\lib\site-packages (from tensorflow_datasets) (0.1.8)
# Requirement already satisfied: immutabledict in d:\school captian\lib\site-packages (from tensorflow_datasets) (4.2.0)
# Requirement already satisfied: numpy in d:\school captian\lib\site-packages (from tensorflow_datasets) (1.26.4)
# Requirement already satisfied: promise in d:\school captian\lib\site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in d:\school captian\lib\site-packages (from tensorflow_datasets) (4.25.4)
# Requirement already satisfied: psutil in d:\school captian\lib\site-packages (from tensorflow_datasets) (5.9.0)
# Requirement already satisfied: pyarrow in d:\school captian\lib\site-packages (from tensorflow_datasets) (14.0.2)
# Requirement already satisfied: requests>=2.19.0 in d:\school captian\lib\site-packages (from tensorflow_datasets) (2.32.2)
# Requirement already satisfied: simple-parsing in d:\school captian\lib\site-packages (from tensorflow_datasets) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in d:\school captian\lib\site-packages (from tensorflow_datasets) (1.15.0)
# Requirement already satisfied: termcolor in d:\school captian\lib\site-packages (from tensorflow_datasets) (2.4.0)
# Requirement already satisfied: toml in d:\school captian\lib\site-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in d:\school captian\lib\site-packages (from tensorflow_datasets) (4.66.4)
# Requirement already satisfied: wrapt in d:\school captian\lib\site-packages (from tensorflow_datasets) (1.14.1)
# Requirement already satisfied: etils>=1.9.1 in d:\school captian\lib\site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (1.9.4)
# Requirement already satisfied: fsspec in d:\school captian\lib\site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (2024.3.1)
# Requirement already satisfied: importlib_resources in d:\school captian\lib\site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (6.4.4)
# Requirement already satisfied: typing_extensions in d:\school captian\lib\site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (4.11.0)
# Requirement already satisfied: zipp in d:\school captian\lib\site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\school captian\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\school captian\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\school captian\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\school captian\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2024.7.4)
# Requirement already satisfied: colorama in d:\school captian\lib\site-packages (from click->tensorflow_datasets) (0.4.6)
# Requirement already satisfied: six in d:\school captian\lib\site-packages (from promise->tensorflow_datasets) (1.16.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in d:\school captian\lib\site-packages (from simple-parsing->tensorflow_datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in d:\school captian\lib\site-packages (from tensorflow-metadata->tensorflow_datasets) (1.65.0)

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
  
import tensorflow as tf
import tensorflow_datasets as tfds

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare the Dataset

# %% [markdown]
# You will load the MNIST data from TFDS into train and test sets. Let's first define a preprocessing function for normalizing and flattening the images. Since we'll be training an autoencoder, this will return `image, image` because the input will also be the target or label while training.

# %%
def map_image(image, label):
  '''Normalizes and flattens the image. Returns image as input and label.'''
  image = tf.cast(image, dtype=tf.float32)
  image = image / 255.0
  image = tf.reshape(image, shape=(784,))

  return image, image

# %%
# Load the train and test sets from TFDS

BATCH_SIZE = 128
SHUFFLE_BUFFER_SIZE = 1024

train_dataset = tfds.load('mnist', as_supervised=True, split="train")
train_dataset = train_dataset.map(map_image)
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE).repeat()

test_dataset = tfds.load('mnist', as_supervised=True, split="test")
test_dataset = test_dataset.map(map_image)
test_dataset = test_dataset.batch(BATCH_SIZE).repeat()

# %% [markdown]
# ## Build the Model

# %% [markdown]
# You will now build a simple autoencoder to ingest the data. Like before, the encoder will compress the input and reconstructs it in the decoder output. ![Autoencoder Flowchart](auto.png)

# %%
#Bulid the Model
def auto(inputs):
    encoder = tf.keras.layers.Dense(units = 32 , activation = "relu")(inputs) #output is 32 
    decoder = tf.keras.layers.Dense(units = 784 , activation = "sigmoid")(encoder) 
    return encoder , decoder
    
# set the input shape
inputs = tf.keras.layers.Input(shape = (784,))

# get the encoder and decoder output
encoder_output , decoder_output  = auto(inputs)

# setup the encoder Model because you will visualize its output later
encoder = tf.keras.Model(inputs = inputs , outputs = encoder_output)

# setup the autoencoder Model
autoencoder = tf.keras.Model(inputs = inputs , outputs = decoder_output)

# %%
autoencoder.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │          25,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 784)                 │          25,872 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 50,992 (199.19 KB)
#  Trainable params: 50,992 (199.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compile the Model

# %% [markdown]
# You will setup the model for training. You can use binary crossentropy to measure the loss between pixel values that range from 0 (black) to 1 (white).

# %%
# Compile the model using Adam Optimizer , binary_crossentropy and  metrics=['accuracy']
autoencoder.compile(optimizer='adam', 
                    loss='binary_crossentropy', 
                    metrics=['accuracy'])

# %% [markdown]
# ## Train the Model

# %%
# train the model using train_dataset,steps_per_epoch=step,epochs=10
step = int(60000 / BATCH_SIZE)
history = autoencoder.fit(train_dataset, steps_per_epoch=step, epochs=50)
# Out:
# Epoch 1/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0124 - loss: 0.0925
# Epoch 2/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0127 - loss: 0.0925
# Epoch 3/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0117 - loss: 0.0925
# Epoch 4/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0127 - loss: 0.0925
# Epoch 5/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0131 - loss: 0.0925
# Epoch 6/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0129 - loss: 0.0925
# Epoch 7/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0129 - loss: 0.0924
# Epoch 8/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0133 - loss: 0.0925
# Epoch 9/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0126 - loss: 0.0925
# Epoch 10/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0128 - loss: 0.0924
# Epoch 11/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0127 - loss: 0.0924
# Epoch 12/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0129 - loss: 0.0925
# Epoch 13/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0130 - loss: 0.0924
# Epoch 14/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0134 - loss: 0.0925
# Epoch 15/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0128 - loss: 0.0924
# Epoch 16/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0129 - loss: 0.0925
# Epoch 17/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0129 - loss: 0.0925
# Epoch 18/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0124 - loss: 0.0925
# Epoch 19/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0124 - loss: 0.0924
# Epoch 20/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0122 - loss: 0.0924
# Epoch 21/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0128 - loss: 0.0923
# Epoch 22/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0121 - loss: 0.0924
# Epoch 23/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0123 - loss: 0.0924
# Epoch 24/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0125 - loss: 0.0924
# Epoch 25/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0121 - loss: 0.0924
# Epoch 26/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0126 - loss: 0.0924
# Epoch 27/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0121 - loss: 0.0924
# Epoch 28/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0122 - loss: 0.0924
# Epoch 29/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0123 - loss: 0.0925
# Epoch 30/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0123 - loss: 0.0925
# Epoch 31/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0123 - loss: 0.0924
# Epoch 32/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0121 - loss: 0.0924
# Epoch 33/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0121 - loss: 0.0924
# Epoch 34/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0119 - loss: 0.0924
# Epoch 35/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0123 - loss: 0.0924
# Epoch 36/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0126 - loss: 0.0924
# Epoch 37/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0122 - loss: 0.0925
# Epoch 38/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0125 - loss: 0.0924
# Epoch 39/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0125 - loss: 0.0924
# Epoch 40/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0125 - loss: 0.0924
# Epoch 41/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0127 - loss: 0.0924
# Epoch 42/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0122 - loss: 0.0924
# Epoch 43/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0121 - loss: 0.0924
# Epoch 44/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0119 - loss: 0.0924
# Epoch 45/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0128 - loss: 0.0923
# Epoch 46/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0125 - loss: 0.0925
# Epoch 47/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0124 - loss: 0.0924
# Epoch 48/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0118 - loss: 0.0923
# Epoch 49/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0128 - loss: 0.0923
# Epoch 50/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0121 - loss: 0.0922

# %% [markdown]
# ## Display sample results
#
# You can now visualize the results. The utility functions below will help in plotting the encoded and decoded values.

# %%
def display_one_row(disp_images, offset, shape=(28, 28)):
  '''Display sample outputs in one row.'''
  for idx, test_image in enumerate(disp_images):
    plt.subplot(3, 10, offset + idx + 1)
    plt.xticks([])
    plt.yticks([])
    test_image = np.reshape(test_image, shape)
    plt.imshow(test_image, cmap='gray')


def display_results(disp_input_images, disp_encoded, disp_predicted, enc_shape=(8,4)):
  '''Displays the input, encoded, and decoded output values.'''
  plt.figure(figsize=(15, 5))
  display_one_row(disp_input_images, 0, shape=(28,28,))
  display_one_row(disp_encoded, 10, shape=enc_shape)
  display_one_row(disp_predicted, 20, shape=(28,28,))

# %%
# take 1 batch of the dataset
test_dataset = test_dataset.take(1)

# take the input images and put them in a list
output_samples = []
for input_image, image in tfds.as_numpy(test_dataset):
      output_samples = input_image

# pick 10 random numbers to be used as indices to the list above
idxs = np.random.choice(BATCH_SIZE, size=10)

# get the encoder output
encoded_predicted = encoder.predict(test_dataset)

# get a prediction for the test batch
simple_predicted = autoencoder.predict(test_dataset)

# display the 10 samples, encodings and decoded values!
display_results(output_samples[idxs], encoded_predicted[idxs], simple_predicted[idxs])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %%
import matplotlib.pyplot as plt

# Retrieve accuracy values from the history object
accuracy = history.history['accuracy']

# Plot the accuracy
plt.plot(accuracy)
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Retrieve accuracy values from the history object
accuracy = history.history['loss']

# Plot the accuracy
plt.plot(accuracy)
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.grid(True)
plt.show()

# %% [markdown]
# ## DEEP_AUTO_ENCODER

# %%
def deep_Autocoder(inputs):
    encoder = tf.keras.layers.Dense(units = 128 , activation = 'relu')(inputs)
    encoder = tf.keras.layers.Dense(units = 64 , activation = 'relu')(encoder)
    encoder = tf.keras.layers.Dense(units = 32, activation = 'relu')(encoder)
    decoder = tf.keras.layers.Dense(units = 64, activation = 'relu')(encoder)
    decoder = tf.keras.layers.Dense(units = 128, activation = 'relu')(decoder)
    decoder = tf.keras.layers.Dense(units = 784, activation = 'sigmoid')(decoder)
    return encoder , decoder 


deep_encoder_output , deep_decoder_output = deep_Autocoder(inputs)

encoder = tf.keras.Model(inputs = inputs , outputs = deep_encoder_output)
deep_autoencoder = tf.keras.Model(inputs = inputs , outputs = deep_decoder_output)

# %%
deep_autoencoder.summary()
# Out:
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_44 (Dense)                     │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_45 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_46 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_47 (Dense)                     │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_48 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 784)                 │         101,136 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 222,384 (868.69 KB)
#  Trainable params: 222,384 (868.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
deep_autoencoder.compile(optimizer='adam', 
                    loss='binary_crossentropy', 
                    metrics=['accuracy'])

# %%
# train the model using train_dataset,steps_per_epoch=step,epochs=10
step = int(60000 / BATCH_SIZE)
history = deep_autoencoder.fit(train_dataset, steps_per_epoch=step, epochs=50)
# Out:
# Epoch 1/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.0095 - loss: 0.2771
# Epoch 2/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0108 - loss: 0.1351
# Epoch 3/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0113 - loss: 0.1189
# Epoch 4/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0109 - loss: 0.1113
# Epoch 5/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0115 - loss: 0.1064
# Epoch 6/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0113 - loss: 0.1025
# Epoch 7/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0119 - loss: 0.0999
# Epoch 8/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0111 - loss: 0.0979
# Epoch 9/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0127 - loss: 0.0961
# Epoch 10/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0128 - loss: 0.0947
# Epoch 11/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0131 - loss: 0.0935
# Epoch 12/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0133 - loss: 0.0922
# Epoch 13/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0140 - loss: 0.0913
# Epoch 14/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0135 - loss: 0.0907
# Epoch 15/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0137 - loss: 0.0900
# Epoch 16/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0147 - loss: 0.0893
# Epoch 17/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0144 - loss: 0.0888
# Epoch 18/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0148 - loss: 0.0882
# Epoch 19/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0138 - loss: 0.0877
# Epoch 20/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0146 - loss: 0.0873
# Epoch 21/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0150 - loss: 0.0867
# Epoch 22/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0142 - loss: 0.0864
# Epoch 23/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0136 - loss: 0.0861
# Epoch 24/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0149 - loss: 0.0859
# Epoch 25/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0154 - loss: 0.0856
# Epoch 26/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0146 - loss: 0.0853
# Epoch 27/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0143 - loss: 0.0851
# Epoch 28/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0152 - loss: 0.0850
# Epoch 29/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0152 - loss: 0.0849
# Epoch 30/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0149 - loss: 0.0847
# Epoch 31/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0144 - loss: 0.0844
# Epoch 32/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0153 - loss: 0.0843
# Epoch 33/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0142 - loss: 0.0841
# Epoch 34/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0141 - loss: 0.0841
# Epoch 35/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0144 - loss: 0.0840
# Epoch 36/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0147 - loss: 0.0840
# Epoch 37/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0145 - loss: 0.0838
# Epoch 38/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0150 - loss: 0.0837
# Epoch 39/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0159 - loss: 0.0837
# Epoch 40/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0150 - loss: 0.0836
# Epoch 41/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0143 - loss: 0.0834
# Epoch 42/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0153 - loss: 0.0834
# Epoch 43/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0138 - loss: 0.0833
# Epoch 44/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0141 - loss: 0.0833
# Epoch 45/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0148 - loss: 0.0832
# Epoch 46/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0143 - loss: 0.0832
# Epoch 47/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0139 - loss: 0.0830
# Epoch 48/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0143 - loss: 0.0830
# Epoch 49/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0145 - loss: 0.0829
# Epoch 50/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0143 - loss: 0.0829

# %%
def display_one_row(disp_images, offset, shape=(28, 28)):
  '''Display sample outputs in one row.'''
  for idx, test_image in enumerate(disp_images):
    plt.subplot(3, 10, offset + idx + 1)
    plt.xticks([])
    plt.yticks([])
    test_image = np.reshape(test_image, shape)
    plt.imshow(test_image, cmap='gray')


def display_results(disp_input_images, disp_encoded, disp_predicted, enc_shape=(8,4)):
  '''Displays the input, encoded, and decoded output values.'''
  plt.figure(figsize=(15, 5))
  display_one_row(disp_input_images, 0, shape=(28,28,))
  display_one_row(disp_encoded, 10, shape=enc_shape)
  display_one_row(disp_predicted, 20, shape=(28,28,))

# %%
# take 1 batch of the dataset
test_dataset = test_dataset.take(1)

# take the input images and put them in a list
output_samples = []
for input_image, image in tfds.as_numpy(test_dataset):
      output_samples = input_image

# pick 10 random numbers to be used as indices to the list above
idxs = np.random.choice(BATCH_SIZE, size=10)

# get the encoder output
encoded_predicted = encoder.predict(test_dataset)

# get a prediction for the test batch
simple_predicted = autoencoder.predict(test_dataset)

# display the 10 samples, encodings and decoded values!
display_results(output_samples[idxs], encoded_predicted[idxs], simple_predicted[idxs])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
import matplotlib.pyplot as plt

# Retrieve accuracy values from the history object
accuracy = history.history['accuracy']

# Plot the accuracy
plt.plot(accuracy)
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Retrieve accuracy values from the history object
accuracy = history.history['accuracy']

# Plot the accuracy
plt.plot(accuracy)
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
